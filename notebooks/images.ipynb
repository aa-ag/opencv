# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib.inline
from IPython.display import Image
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
Image(filename="206x198.png")

# %%
grey_scale_image = cv2.imread("206x198.png",0)
print(grey_scale_image)
# Out:
# [[ 11  11  11 ...   0 128 255]
#  [ 11  11  11 ...   1 128 255]
#  [ 11  11  11 ...   1 128 255]
#  ...
#  [ 11  11  11 ...   0 125 239]
#  [ 11  11  11 ... 118 124 136]
#  [ 11  11  11 ... 226 120  48]]

# %%
print("Image Size: ", grey_scale_image.shape)
print("Image Type: ", grey_scale_image.dtype)
# Out:
# Image Size:  (198, 206)
# Image Type:  uint8

# %%
plt.imshow(grey_scale_image, cmap="gray")

# %%
Image("cocacolalogo.jpeg")

# %%
grey_scale_image = cv2.imread("cocacolalogo.jpeg",1)
print("Image Size: ", grey_scale_image.shape)
print("Image Type: ", grey_scale_image.dtype)
print(grey_scale_image)
